# %%
import C_check_clts_conformity
import codecs
# Out:
# 2017-11-15 09:35:03,721 [WARNING] Module 'sklearn' could not be loaded. Some methods may not work properly.
# 2017-11-15 09:35:03,722 [WARNING] Module 'igraph' could not be loaded. Some methods may not work properly.

# %%
profile_as_segments =\
    C_check_clts_conformity.profile_to_segment_list('D_profile.tsv')
aggregated =\
    C_check_clts_conformity.aggregate_segments(profile_as_segments)
t =\
    C_check_clts_conformity.make_table(aggregated, verbose=False)

with codecs.open('CLTS_out.txt', 'w', 'utf-8') as text_file:
    s = C_check_clts_conformity.tabulate_print_table(t)
    text_file.write(s)
    
# -> Refer to CLTS_out.txt
