# %%
from pyclts.clts import CLTS
from lingpy.read.csv import csv2list
from collections import defaultdict

# %%
# Make sure that the CLTS data is in lib/PYVER/site-packages/data.
bipa = CLTS('bipa')
bipa['a:']
# Out:
# Vowel(clts=<pyclts.clts.CLTS object at 0x10c534e48>, grapheme='aː', source=None, generated=False, note=None, base=None, alias=None, unknown=None, roundedness='unrounded', height='open', nasalization=None, frication=None, duration='long', phonation=None, release=None, syllabicity=None, pharyngealization=None, rhotacization=None, centrality='front', glottalization=None, velarization=None)

# %%
class SegmentsInProfile:
    """Description."""
    
    def __init__(self, segment_list, profile_line):
        self.segment_list = segment_list
        self.profile_line = profile_line
        
        self.segment_info = {
            profile_line: segment_list
        }

# %%
def profile_to_segment_list(profile_tsv_path):
    row_number = 1
    segments = []
    
    for row in csv2list(profile_tsv_path)[1:]:
        row_number += 1
        segments.append(
            SegmentsInProfile(row[1].split(), row_number)
        )
        
    return segments

# %%
def check_conformity(segment_dict):
    conformity_dict = {}
    
    def check_bipa(segment_bipa_check):
        is_in_bipa = segment_bipa_check in bipa
        
        return [segment_bipa_check, is_in_bipa]
    
    for line, segment_list in segment_dict.items():
        local_segments = []
        
        for segment in segment_list:
            
            local_segments.append(check_bipa(segment))
        
        conformity_dict = {
            line: local_segments
        }
        
    return conformity_dict

# %%
def aggregate_segments(segment_dicts):
    aggregated_segments = defaultdict(list)
    
    for segment_dict in segment_dicts:
        for line, segments in segment_dict.segment_info.items():
            for segment in segments:
                    aggregated_segments[segment].append(line)
                    
    return aggregated_segments

# %%
aggregated = aggregate_segments(profile_to_segment_list('D_profile.tsv'))

# %%
def in_bipa(char):
    bchar = bipa[char]
    
    if bchar.type == 'unknownsound':
        return char, '?', 'unknown'
    if bchar.generated:
        return char, str(bchar), 'generated'
    if str(bchar) != char:
        return char, str(bchar), 'normalized'
    return char, str(bchar), ''

# %%
print(aggregated) # build table with tabulate
# Out:
# defaultdict(<class 'list'>, {'+': [2, 3, 20], 'NULL': [4, 5, 6, 7, 9, 10, 11, 12, 13, 14, 16, 17, 18, 19, 21, 22, 23, 26, 27, 28, 82, 85, 136, 303, 381, 392, 393, 395], '_': [8], 'ː': [15], '→/⁵⁵': [24], 'a': [25, 29, 30, 31, 32, 33, 34, 35, 36], '⁵': [29, 30, 38, 43, 48, 49, 57, 58, 66, 69, 72, 74, 75, 88, 89, 95, 110, 111, 118, 122, 127, 128, 141, 142, 149, 152, 157, 160, 161, 168, 175, 179, 180, 187, 191, 196, 201, 205, 210, 211, 223, 227, 228, 235, 240, 245, 251, 252, 257, 268, 273, 276, 282, 283, 286, 292, 296, 299, 304, 305, 314, 319, 323, 326, 329, 347, 348, 355, 360, 365, 366, 372, 375, 382, 386, 390, 396, 401], '¹': [31, 32, 39, 44, 53, 54, 62, 63, 67, 70, 76, 77, 90, 91, 100, 112, 113, 120, 123, 143, 144, 150, 153, 158, 162, 163, 169, 176, 181, 182, 188, 192, 197, 204, 208, 212, 213, 229, 230, 236, 241, 247, 254, 258, 267, 269, 274, 275, 277, 284, 287, 290, 293, 297, 300, 306, 307, 315, 320, 324, 327, 330, 349, 350, 356, 361, 367, 368, 373, 377, 383, 387, 391, 397, 400], '⁵¹': [33, 40, 45, 50, 51, 59, 60, 68, 71, 78, 92, 101, 114, 124, 131, 145,
# %%
in_bipa(list(aggregated.keys())[4])
# Out:
# ('→/⁵⁵', '⁵⁵', 'normalilzed')

# %%
def calculate_conformity(conformity_dict):
    # TODO: Expand to check the *proper* thing (ask Mattis) and
    # improve the report.
    
    for line, segment_list in conformity_dict.items():
        for checked_segment in segment_list:
            if not checked_segment[1]:
                print(f"Problematic segment {checked_segment[0]} in line {line}.")

# %%
dogon_segments = profile_to_segment_list('D_profile.tsv')

print(dogon_segments[30].segment_info)
# Out:
# {32: ['a', '¹']}

# %%
check_conformity(dogon_segments[30].segment_info)
# Out:
# {32: [['a', True], ['¹', True]]}

# %%
for dogon_segment in dogon_segments:
    to_analyse = check_conformity(dogon_segment.segment_info)
    calculate_conformity(to_analyse)

# calculate_conformity(check_conformity(dogon_segments[10].segment_info))
# Out:
# Problematic segment NULL in line 4.
# Problematic segment NULL in line 5.
# Problematic segment NULL in line 6.
# Problematic segment NULL in line 7.
# Problematic segment NULL in line 9.
# Problematic segment NULL in line 10.
# Problematic segment NULL in line 11.
# Problematic segment NULL in line 12.
# Problematic segment NULL in line 13.
# Problematic segment NULL in line 14.
# Problematic segment ː in line 15.
# Problematic segment NULL in line 16.
# Problematic segment NULL in line 17.
# Problematic segment NULL in line 18.
# Problematic segment NULL in line 19.
# Problematic segment NULL in line 21.
# Problematic segment NULL in line 22.
# Problematic segment NULL in line 23.
# Problematic segment →/⁵⁵ in line 24.
# Problematic segment NULL in line 26.
# Problematic segment NULL in line 27.
# Problematic segment NULL in line 28.
# Problematic segment ãː in line 43.
# Problematic segment ∼ in line 43.
# Problematic segment ãː in line 44.
# Problematic segment ∼ in line 44.
# Problematic segment ãː in line 45.
# Problematic segment ∼ in line 45.
# Problematic segment ãː in line 46.
# Problematic segment ∼ in line 46.
# Problematic segment ∼ in line 47.
# Problematic segment âː in line 50.
# Problematic segment âː in line 51.
# Problematic segment ãː in line 57.
# Problematic segment ∼ in line 57.
# Problematic segment ãː in line 58.
# Problematic segment ∼ in line 58.
# Problematic segment ãː in line 59.
# Problematic segment ∼ in line 59.
# Problematic segment ãː in line 60.
# Problematic segment ∼ in line 60.
# Problematic segment ãː in line 61.
# Problematic segment ∼ in line 61.
# Problematic segment ã̀ː in line 62.
# Problematic segment ∼ in line 62.
# Problematic segment ã̀ː in line 63.
# Problematic segment ∼ in line 63.
# Problematic segment ã̀ː in line 64.
# Problematic segment ∼ in line 64.
# Problematic segment ã̀ː in line 65.
# Problematic segment ∼ in line 65.
# Problematic segment ∼ in line 69.
# Problematic segment æ̃̀ː in line 70.
# Problematic segment ∼ in line 70.
# Problematic segment ∼ in line 71.
# Problematic segment ∼ in line 72.
# Problematic segment ã in line 73.
# Problematic segment ∼ in line 73.
# Problematic segment ã in line 74.
# Problematic segment ∼ in line 74.
# Problematic segment ã in line 75.
# Problematic segment ∼ in line 75.
# Problematic segment ã in line 76.
# Problematic segment ∼ in line 76.
# Problematic segment ã in line 77.
# Problematic segment ∼ in line 77.
# Problematic segment ã in line 78.
# Problematic segment ∼ in line 78.
# Problematic segment ã in line 79.
# Problematic segment ∼ in line 79.
# Problematic segment NULL in line 82.
# Problematic segment NULL in line 85.
# Problematic segment ∼ in line 94.
# Problematic segment ∼ in line 95.
# Problematic segment ɔ᷈ in line 96.
# Problematic segment ɔ́ː in line 99.
# Problematic segment ɔ̌ː in line 102.
# Problematic segment ɔ᷈ː in line 103.
# Problematic segment ∼ in line 104.
# Problematic segment ∼ in line 105.
# Problematic segment ∼ in line 106.
# Problematic segment ∼ in line 107.
# Problematic segment ∼ in line 108.
# Problematic segment ∼ in line 109.
# Problematic segment ∼ in line 117.
# Problematic segment ∼ in line 118.
# Problematic segment ɔ̃̀ː in line 120.
# Problematic segment ∼ in line 120.
# Problematic segment ∼ in line 121.
# Problematic segment ∼ in line 122.
# Problematic segment ɔ̃̀ː in line 123.
# Problematic segment ∼ in line 123.
# Problematic segment ∼ in line 124.
# Problematic segment ∼ in line 125.
# Problematic segment ∼ in line 126.
# Problematic segment ∼ in line 127.
# Problematic segment ∼ in line 128.
# Problematic segment ɔ̃̀ in line 129.
# Problematic segment ∼ in line 129.
# Problematic segment ɔ̃̀ in line 130.
# Problematic segment ∼ in line 130.
# Problematic segment ∼ in line 131.
# Problematic segment ∼ in line 132.
# Problematic segment ∼ in line 133.
# Problematic segment NULL in line 136.
# Problematic segment dʷ in line 139.
# Problematic segment ẽː in line 157.
# Problematic segment ∼ in line 157.
# Problematic segment ẽː in line 158.
# Problematic segment ∼ in line 158.
# Problematic segment ẽː in line 159.
# Problematic segment ∼ in line 159.
# Problematic segment ẽː in line 168.
# Problematic segment ∼ in line 168.
# Problematic segment ẽː in line 169.
# Problematic segment ∼ in line 169.
# Problematic segment ∼ in line 170.
# Problematic segment ∼ in line 171.
# Problematic segment ẽː in line 172.
# Problematic segment ∼ in line 172.
# Problematic segment ẽː in line 173.
# Problematic segment ∼ in line 173.
# Problematic segment ẽ in line 174.
# Problematic segment ∼ in line 174.
# Problematic segment ẽ in line 175.
# Problematic segment ∼ in line 175.
# Problematic segment ẽ in line 176.
# Problematic segment ∼ in line 176.
# Problematic segment ẽ in line 177.
# Problematic segment ∼ in line 177.
# Problematic segment ∼ in line 186.
# Problematic segment ∼ in line 187.
# Problematic segment ∼ in line 188.
# Problematic segment ∼ in line 189.
# Problematic segment ∼ in line 196.
# Problematic segment ∼ in line 197.
# Problematic segment ∼ in line 198.
# Problematic segment ∼ in line 199.
# Problematic segment ∼ in line 205.
# Problematic segment ∼ in line 206.
# Problematic segment ∼ in line 207.
# Problematic segment ∼ in line 208.
# Problematic segment ∼ in line 209.
# Problematic segment ∼ in line 210.
# Problematic segment ∼ in line 211.
# Problematic segment ∼ in line 212.
# Problematic segment ∼ in line 213.
# Problematic segment ∼ in line 214.
# Problematic segment ∼ in line 215.
# Problematic segment ʷ in line 225.
# Problematic segment ĩː in line 240.
# Problematic segment ∼ in line 240.
# Problematic segment ĩː in line 241.
# Problematic segment ∼ in line 241.
# Problematic segment ĩː in line 242.
# Problematic segment ∼ in line 242.
# Problematic segment ĩː in line 243.
# Problematic segment ∼ in line 243.
# Problematic segment ĩː in line 250.
# Problematic segment ∼ in line 250.
# Problematic segment ĩː in line 251.
# Problematic segment ∼ in line 251.
# Problematic segment ∼ in line 252.
# Problematic segment ĩː in line 253.
# Problematic segment ∼ in line 253.
# Problematic segment ĩː in line 254.
# Problematic segment ∼ in line 254.
# Problematic segment ĩː in line 255.
# Problematic segment ∼ in line 255.
# Problematic segment ĩ in line 256.
# Problematic segment ĩ́ in line 257.
# Problematic segment ∼ in line 257.
# Problematic segment ĩ in line 258.
# Problematic segment ∼ in line 258.
# Problematic segment ĩ in line 259.
# Problematic segment ∼ in line 259.
# Problematic segment ĩ in line 260.
# Problematic segment ∼ in line 260.
# Problematic segment ∼ in line 281.
# Problematic segment NULL in line 303.
# Problematic segment ∼ in line 318.
# Problematic segment õː in line 319.
# Problematic segment ∼ in line 319.
# Problematic segment õː in line 320.
# Problematic segment ∼ in line 320.
# Problematic segment õː in line 321.
# Problematic segment ∼ in line 321.
# Problematic segment õː in line 322.
# Problematic segment ∼ in line 322.
# Problematic segment õ in line 323.
# Problematic segment ∼ in line 323.
# Problematic segment õ in line 324.
# Problematic segment ∼ in line 324.
# Problematic segment õ in line 325.
# Problematic segment ∼ in line 325.
# Problematic segment ∼ in line 326.
# Problematic segment ∼ in line 327.
# Problematic segment ∼ in line 328.
# Problematic segment r̃ in line 338.
# Problematic segment ∼ in line 338.
# Problematic segment r̃ in line 339.
# Problematic segment ∼ in line 339.
# Problematic segment ū in line 351.
# Problematic segment ũ in line 354.
# Problematic segment ∼ in line 354.
# Problematic segment ũː in line 360.
# Problematic segment ∼ in line 360.
# Problematic segment ũː in line 361.
# Problematic segment ∼ in line 361.
# Problematic segment ũː in line 362.
# Problematic segment ∼ in line 362.
# Problematic segment ũː in line 363.
# Problematic segment ∼ in line 363.
# Problematic segment ũ in line 364.
# Problematic segment ∼ in line 364.
# Problematic segment ũ in line 365.
# Problematic segment ∼ in line 365.
# Problematic segment ũ in line 366.
# Problematic segment ∼ in line 366.
# Problematic segment ũ in line 367.
# Problematic segment ∼ in line 367.
# Problematic segment ũ in line 368.
# Problematic segment ∼ in line 368.
# Problematic segment ũ in line 369.
# Problematic segment ∼ in line 369.
# Problematic segment ũ in line 370.
# Problematic segment ∼ in line 370.
# Problematic segment ũ in line 371.
# Problematic segment ũː in line 375.
# Problematic segment ∼ in line 375.
# Problematic segment ũː in line 376.
# Problematic segment ∼ in line 376.
# Problematic segment ũː in line 377.
# Problematic segment ∼ in line 377.
# Problematic segment ũː in line 378.
# Problematic segment ∼ in line 378.
# Problematic segment ũː in line 379.
# Problematic segment ∼ in line 379.
# Problematic segment NULL in line 381.
# Problematic segment ∼ in line 388.
# Problematic segment ∼ in line 389.
# Problematic segment ∼ in line 390.
# Problematic segment ∼ in line 391.
# Problematic segment NULL in line 392.
# Problematic segment NULL in line 393.
# Problematic segment NULL in line 395.
# Problematic segment ∼ in line 399.
# Problematic segment ∼ in line 400.
# Problematic segment ∼ in line 401.
# Problematic segment ∼ in line 402.
# Problematic segment ∼ in line 408.
# Problematic segment ꜜ/⁵¹ in line 409.
# Problematic segment ∼ in line 411.

# %%
# Notes for output:
# sound source = source_string
# bipa suggestion = bipa['source_string']
# normalized/alias/generated based on in_bipa function (see Mattis' comment)
